# %%
import pandas as pd
import numpy as np
import os 
from datetime import date
from pathlib import PurePath

# %%
path = PurePath(os.getcwd(),'ventas', 'Bajio 18.txt')
df = pd.read_table(path, delimiter = ';', encoding="iso-8859-1")
df
# Out:
#            Año  Mes_Numero     cli_cve  pto_Cve  \
# 0         2018          10  1620004476    97290
# 1         2018          12   603904109      382
# 2         2018           9   620138527    97820
# 3         2018          12  1601061935    99457
# 4         2018          10   604205525    99458
# ...        ...         ...         ...      ...
# 17332250  2018          12  1605015665      379
# 17332251  2018          11   603404014      844
# 17332252  2018          10   610155023    97289
# 17332253  2018          12   620152662     2715
# 17332254  2018           9   620113406    99055
#
#                                                  pto_Nombre          CU  \
# 0         POWERADE Moras 1L 6pk                         ...   21.133760
# 1         SIDRAL 2 LT 8 G PETNR                         ...   11.271340
# 2         FUZE TEA DURAZNO 600 ML                       ...    1.902039
# 3         Botellin PET Durazno 237ml 6pk                ...    1.000000
# 4         Botellin PET Guayaba 237ml 6pk                ...    2.000000
# ...                                                     ...         ...
# 17332250  Fanta Naranja 355 ml 12PK lata                ...  150.000000
# 17332251  FANTA FRESA 600 ML PETNR 12 PK PRECIADO       ...    1.902042
# 17332252  POWERADE Naranja 1L 6pk                       ...    4.226752
# 17332253  CC sin azucar 500ml VR 24pk                   ...    8.453504
# 17332254  Monster 473ML 4PK LT                          ...    1.999998
#
#              CF         CFC      TA  Ing_Neto_SA_SIEPS  Ing_Bruto_SIEPS
# 0          20.0   10.000000   120.0            1870.65          1870.65
# 1           4.0    4.000000    32.0             394.40           438.24
# 2           3.0    0.750000    18.0             136.50           195.00
# 3           4.0    1.000000    24.0             136.00           136.00
# 4           8.0    2.000000    48.0             264.00           264.00
# ...         ...         ...     ...                ...              ...
# 17332250  200.0  100.000000  2400.0           18063.40         20070.40
# 17332251    1.5    0.750000    18.0             107.28           107.28
# 17332252    4.0    2.000000    24.0             374.12           374.12
# 17332253    4.0    4.000000    96.0               0.00             0.00
# 17332254    6.0    1.000002    24.0             504.30           504.30
#
# [17332255 rows x 11 columns]

# %%
ndf = df[['cli_cve','pto_Nombre','CU']].groupby(['cli_cve','pto_Nombre']).sum()
ndf = ndf.reset_index()
ndf['cli_cve'] = ndf['cli_cve'].apply(lambda x: 'Tienda No {}'.format(str(x)).strip())
ndf['pto_Nombre'] = ndf['pto_Nombre'].str.upper()
ndf['pto_Nombre'] = ndf['pto_Nombre'].apply(lambda x: x.strip())
ndf['CU'] = pd.to_numeric(ndf['CU'])
ndf= ndf.dropna()
ndf
# Out:
#                       cli_cve                              pto_Nombre  \
# 0         Tienda No 220056285               ADES CHOCOLATE 200 ML 4PK
# 1         Tienda No 220056285                    CC 355ML NR PET 12PK
# 2         Tienda No 220056285                    CC 500ML NR PET 12PK
# 3         Tienda No 220056285  CC COLA BOT 500ML R VID 1X24U (U ALIG)
# 4         Tienda No 220056285             CC CLASICA 355 ML 12PK LATA
# ...                       ...                                     ...
# 6930011  Tienda No 1980000512         V.FRUT PON CITR 600ML PETNR 12P
# 6930012  Tienda No 1980000512             YOLI LIMON BOT 600L NR 12PK
# 6930013  Tienda No 1980000565                    CC 500ML NR PET 12PK
# 6930014  Tienda No 1980000566             CC CLASICA 355 ML 12PK LATA
# 6930015  Tienda No 1980000566               CC LIGHT 355 ML 12PK LATA
#
#                 CU
# 0         0.422676
# 1        11.250000
# 2        34.870704
# 3        38.040768
# 4         4.500000
# ...            ...
# 6930011  50.721040
# 6930012  20.288416
# 6930013   2.113376
# 6930014   4.500000
# 6930015   4.500000
#
# [6930016 rows x 3 columns]

# %%
ndf.columns = ['tienda','producto','cu']
ndf['category'] = ''
ndf.loc[(ndf['cu'] < ndf['cu'].quantile(.25)),'category'] = 'BAJA VENTA'
ndf.loc[(ndf['cu'] >= ndf['cu'].quantile(.25)) & (ndf['cu'] < ndf['cu'].quantile(.5)),'category'] = 'MEDIA VENTA'
ndf.loc[(ndf['cu'] >= ndf['cu'].quantile(.5)) & (ndf['cu'] < ndf['cu'].quantile(.75)),'category'] = 'ALTA VENTA'
ndf.loc[(ndf['cu'] >= ndf['cu'].quantile(.75)),'category'] = 'MUY ALTA VENTA'
ndf
# Out:
#                        tienda                                producto  \
# 0         Tienda No 220056285               ADES CHOCOLATE 200 ML 4PK
# 1         Tienda No 220056285                    CC 355ML NR PET 12PK
# 2         Tienda No 220056285                    CC 500ML NR PET 12PK
# 3         Tienda No 220056285  CC COLA BOT 500ML R VID 1X24U (U ALIG)
# 4         Tienda No 220056285             CC CLASICA 355 ML 12PK LATA
# ...                       ...                                     ...
# 6930011  Tienda No 1980000512         V.FRUT PON CITR 600ML PETNR 12P
# 6930012  Tienda No 1980000512             YOLI LIMON BOT 600L NR 12PK
# 6930013  Tienda No 1980000565                    CC 500ML NR PET 12PK
# 6930014  Tienda No 1980000566             CC CLASICA 355 ML 12PK LATA
# 6930015  Tienda No 1980000566               CC LIGHT 355 ML 12PK LATA
#
#                 cu        category
# 0         0.422676      BAJA VENTA
# 1        11.250000     MEDIA VENTA
# 2        34.870704      ALTA VENTA
# 3        38.040768      ALTA VENTA
# 4         4.500000      BAJA VENTA
# ...            ...             ...
# 6930011  50.721040  MUY ALTA VENTA
# 6930012  20.288416      ALTA VENTA
# 6930013   2.113376      BAJA VENTA
# 6930014   4.500000      BAJA VENTA
# 6930015   4.500000      BAJA VENTA
#
# [6930016 rows x 4 columns]

# %%
ndf = ndf[ndf['tienda'].isin(ndf['tienda'].unique()[:100])]
ndf
# Out:
#                    tienda                                producto          cu  \
# 0     Tienda No 220056285               ADES CHOCOLATE 200 ML 4PK    0.422676
# 1     Tienda No 220056285                    CC 355ML NR PET 12PK   11.250000
# 2     Tienda No 220056285                    CC 500ML NR PET 12PK   34.870704
# 3     Tienda No 220056285  CC COLA BOT 500ML R VID 1X24U (U ALIG)   38.040768
# 4     Tienda No 220056285             CC CLASICA 355 ML 12PK LATA    4.500000
# ...                   ...                                     ...         ...
# 4758  Tienda No 600100694             VF GUAYABA 355ML NRPET 12PK   94.500000
# 4759  Tienda No 600100694              VF MANGO BOT 600ML NR 12PK   35.504728
# 4760  Tienda No 600100694         VLLEFRT GYBA BOT 600ML PT NR12P  124.266548
# 4761  Tienda No 600100694         VLLEFRU MZA BOT 600ML NR PET12P   53.257092
# 4762  Tienda No 600100694         VLLEFRU UVA BOT 600M NR PET 12P    8.876182
#
#             category
# 0         BAJA VENTA
# 1        MEDIA VENTA
# 2         ALTA VENTA
# 3         ALTA VENTA
# 4         BAJA VENTA
# ...              ...
# 4758  MUY ALTA VENTA
# 4759      ALTA VENTA
# 4760  MUY ALTA VENTA
# 4761  MUY ALTA VENTA
# 4762     MEDIA VENTA
#
# [4763 rows x 4 columns]

# %%
ndf.to_csv('tiendas.csv')

# %%
ndf = df[['Año','Mes_Numero','pto_Nombre','CU']].copy()
ndf['fecha'] = ndf.apply(lambda x : date(x['Año'],x['Mes_Numero'],1), axis=1)
ndf['pto_Nombre'] = ndf['pto_Nombre'].str.upper()
ndf['pto_Nombre'] = ndf['pto_Nombre'].apply(lambda x : x.strip())
del ndf['Mes_Numero']
del ndf['Año']
ndf

# %%
products = pd.pivot_table(ndf, values='CU', index='pto_Nombre',
                    columns=['fecha'], aggfunc=np.sum, fill_value=0)
products = products.reset_index()
products

# %%
columns = products.columns[1:]
tendencias = products.copy()

def get_trend_serie(value):
    values = []
    for id_column in range(1,len(columns),1):
        values.append(value[columns[id_column]]-value[columns[id_column-1]])
    return values

tendencias['tendencia'] = products.apply(lambda x: get_trend_serie(x),axis=1)


for column in columns:
    del tendencias[column]
    
def get_type_tendece(val):
    val = np.average(val)
    if val > 0:
        return 'ALCISTA'
    elif val == 0:
        return 'ESTABLE'
    elif val < 0:
        return 'A LA BAJA'
    else:
        return ""
    
tendencias['tendencia_type'] = tendencias['tendencia'].apply(lambda x: get_type_tendece(x))
tendencias

# %%
tendencias = tendencias.reset_index(drop=True)
tendencias.columns = ['producto','tendencia','tipo']
tendencias

# %%
tendencias.to_csv('tendencias.csv')

# %%
df = pd.read_csv('input.csv',encoding='iso-8859-1')
df = df[['prod_A','prod_B','estado','canal','gec','lift','confidence', 'sales_a','sales_b','support_b']]

for column in ['prod_A','prod_B','estado','canal','gec']:
    df[column] = df[column].str.upper()
    
df = df.dropna()
df

# %%
df_sales = df[['prod_A','sales_a']]
df_sales.columns = ['product','sales']
df_sales = df_sales.groupby(by=["product"]).sum()
df_sales['category'] = 'NA'

df_sales.loc[(df_sales['sales'] < df_sales['sales'].quantile(.25)),'category'] = 'BAJA VENTA'
df_sales.loc[(df_sales['sales'] >= df_sales['sales'].quantile(.25)) & (df_sales['sales'] < df_sales['sales'].quantile(.5)),'category'] = 'MEDIA VENTA'
df_sales.loc[(df_sales['sales'] >= df_sales['sales'].quantile(.5)) & (df_sales['sales'] < df_sales['sales'].quantile(.75)),'category'] = 'ALTA VENTA'
df_sales.loc[(df_sales['sales'] >= df_sales['sales'].quantile(.75)),'category'] = 'MUY ALTA VENTA'

df_sales = df_sales.reset_index()
df_sales

# %%
df_sales = df_sales.merge(tendencias, left_on='product', right_on='producto', how='inner')
del df_sales['producto']
df_sales

# %%
df =df.merge(df_sales[['product','category','tipo','tendencia']], left_on='prod_B',right_on='product', how='left')
df.columns = df.columns.str.replace('category', 'category_b')
del df['product']
df = df.dropna()
df

# %%
df.to_csv('metrics.csv', index=False)
df_sales.to_csv('sales.csv', index=False)
